# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.model_selection import train_test_split
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ## Load Data
# Define a function that imports all the data from the provided csv files

# %%
csv_paths = glob.glob("data/*.csv")
csv_filenames = [os.path.splitext(os.path.basename(x))[0] for x in csv_paths]

def load_data_from_csv():
    """Loads the csv files to pandas DataFrames and saves
    them in a dictionary with their filenames as keys"""
    data = dict()
    for csv_filename, csv_path in zip(csv_filenames, csv_paths):
        data[csv_filename] = pd.read_csv(csv_path)
    return data

# Load the data to a Dictionary
data = load_data_from_csv()

# %% [markdown]
# Inspect the data, the schema is shown below:
#
# <img src="docs/schema.png">

# %% [markdown]
# ### Inspect data

# %%
for key, values in data.items():
    print(key, "\n")
    print(values.head(), "\n")
    print(values.describe(), "\n")
# Out:
# app_categories
#
#   grouped_categories  Unnamed: 1
# 0              Games           1
# 1           Business           2
# 2          Education           3
# 3          Lifestyle           4
# 4          Utilities           5
#
#        Unnamed: 1
# count   19.000000
# mean    10.000000
# std      5.627314
# min      1.000000
# 25%      5.500000
# 50%     10.000000
# 75%     14.500000
# max     19.000000
#
# app_events
#
#    event_id               app_id  is_installed  is_active
# 0         2  5927333115845830913             1          1
# 1         2 -5720078949152207372             1          0
# 2         2 -1633887856876571208             1          0
# 3         2  -653184325010919369             1          1
# 4         2  8693964245073640147             1          1
#
#            event_id        app_id  is_installed     is_active
# count  3.247307e+07  3.247307e+07    32473067.0  3.247307e+07
# mean   1.625564e+06  1.182779e+18           1.0  3.921094e-01
# std    9.384682e+05  5.360173e+18           0.0  4.882209e-01
# min    2.000000e+00 -9.221157e+18           1.0  0.000000e+00
# 25%    8.134720e+05 -3.474568e+18           1.0  0.000000e+00
# 50%    1.626907e+06  1.387044e+18           1.0  0.000000e+00
# 75%    2.441106e+06  6.043001e+18           1.0  1.000000e+00
# max    3.252948e+06  9.222488e+18           1.0  1.000000e+00
#
# app_labels
#
#                 app_id  label_id
# 0  7324884708820027918       251
# 1 -4494216993218550286       251
# 2  6058196446775239644       406
# 3  6058196446775239644       407
# 4  8694625920731541625       406
#
#              app_id       label_id
# count  4.599430e+05  459943.000000
# mean   1.912461e+17     664.849749
# std    5.269442e+18     192.797736
# min   -9.223281e+18       2.000000
# 25%   -4.305882e+18     548.000000
# 50%    1.083204e+17     714.000000
# 75%    4.830475e+18     795.000000
# max    9.223318e+18    1021.000000
#
# chinese_to_english_brand
#
#   chinese_brand    brand
# 0            三星  samsung
# 1            天语   Ktouch
# 2            海信  hisense
# 3            联想   lenovo
# 4            欧比      obi
#
#        chinese_brand brand
# count             97    97
# unique            97    96
# top               魅族  epai
# freq               1     2
#
# events
#
#    event_id            device_id            timestamp  longitude  latitude
# 0         1    29182687948017175  2016-05-01 00:55:25     121.38     31.24
# 1         2 -6401643145415154744  2016-05-01 00:54:12     103.65     30.97
# 2         3 -4833982096941402721  2016-05-01 00:08:05     106.60     29.70
# 3         4 -6815121365017318426  2016-05-01 00:06:40     104.27     23.28
# 4         5 -5373797595892518570  2016-05-01 00:07:18     115.88     28.66
#
#            event_id     device_id     longitude      latitude
# count  3.252950e+06  3.252950e+06  3.252950e+06  3.252950e+06
# mean   1.626476e+06 -2.685140e+16  7.796192e+01  2.162949e+01
# std    9.390459e+05  5.301236e+18  5.405801e+01  1.569697e+01
# min    1.000000e+00 -9.222957e+18 -1.800000e+02 -3.843000e+01
# 25%    8.132382e+05 -4.616259e+18  0.000000e+00  0.000000e+00
# 50%    1.626476e+06 -1.729953e+16  1.129500e+02  2.802000e+01
# 75%    2.439713e+06  4.549750e+18  1.172100e+02  3.407000e+01
# max    3.252950e+06  9.222540e+18  1.747600e+02  5.994000e+01
#
# gender_age_test
#
#              device_id
# 0  1002079943728939269
# 1 -1547860181818787117
# 2  7374582448058474277
# 3 -6220210354783429585
# 4 -5893464122623104785
#
#           device_id
# count  1.120710e+05
# mean  -2.367461e+16
# std    5.331855e+18
# min   -9.223322e+18
# 25%   -4.661036e+18
# 50%   -3.107321e+16
# 75%    4.581985e+18
# max    9.223069e+18
#
# gender_age_train
#
#              device_id gender  age   group
# 0 -8076087639492063270      M   35  M32-38
# 1 -2897161552818060146      M   35  M32-38
# 2 -8260683887967679142      M   35  M32-38
# 3 -4938849341048082022      M   30  M29-31
# 4   245133531816851882      M   30  M29-31
#
#           device_id           age
# count  7.464500e+04  74645.000000
# mean  -7.491354e+14     31.410342
# std    5.327150e+18      9.868735
# min   -9.223067e+18      1.000000
# 25%   -4.617367e+18     25.000000
# 50%   -1.841362e+16     29.000000
# 75%    4.636656e+18     36.000000
# max    9.222849e+18     96.000000
#
# label_categories
#
#    label_id           category
# 0         1                NaN
# 1         2     game-game type
# 2         3   game-Game themes
# 3         4     game-Art Style
# 4         5  game-Leisure time
#
#           label_id
# count   930.000000
# mean    517.080645
# std     297.858790
# min       1.000000
# 25%     251.250000
# 50%     523.500000
# 75%     778.750000
# max    1021.000000
#
# label_categories_grouped
#
#    label_id           category  Unnamed: 2
# 0         1                NaN         NaN
# 1         2     game-game type         1.0
# 2         3   game-Game themes         1.0
# 3         4     game-Art Style         1.0
# 4         5  game-Leisure time         1.0
#
#           label_id  Unnamed: 2
# count   930.000000  148.000000
# mean    517.080645    2.945946
# std     297.858790    2.903865
# min       1.000000    1.000000
# 25%     251.250000    1.000000
# 50%     523.500000    1.000000
# 75%     778.750000    7.000000
# max    1021.000000   13.000000
#
# phone_brand_device_model
#
#              device_id phone_brand   device_model
# 0 -8890648629457979026          小米             红米
# 1  1277779817574759137          小米           MI 2
# 2  5137427614288105724          三星      Galaxy S4
# 3  3669464369358936369       SUGAR           时尚手机
# 4 -5019277647504317457          三星  Galaxy Note 2
#
#           device_id
# count  1.872450e+05
# mean  -1.426513e+16
# std    5.330527e+18
# min   -9.223322e+18
# 25%   -4.645265e+18
# 50%   -2.619149e+16
# 75%    4.606568e+18
# max    9.223069e+18
#
# sample_submission
#
#              device_id    F23-  F24-26  F27-28  F29-32  F33-42    F43+  \
# 0  1002079943728939269  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 1 -1547860181818787117  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 2  7374582448058474277  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 3 -6220210354783429585  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 4 -5893464122623104785  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
#
#      M22-  M23-26  M27-28  M29-31  M32-38    M39+
# 0  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 1  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 2  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 3  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
# 4  0.0833  0.0833  0.0833  0.0833  0.0833  0.0833
#
#           device_id          F23-        F24-26        F27-28        F29-32  \
# count  1.120710e+05  1.120710e+05  1.120710e+05  1.120710e+05  1.120710e+05
# mean  -2.367461e+16  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# std    5.331855e+18  2.775570e-17  2.775570e-17  2.775570e-17  2.775570e-17
# min   -9.223322e+18  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 25%   -4.661036e+18  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 50%   -3.107321e+16  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 75%    4.581985e+18  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# max    9.223069e+18  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
#
#              F33-42          F43+          M22-        M23-26        M27-28  \
# count  1.120710e+05  1.120710e+05  1.120710e+05  1.120710e+05  1.120710e+05
# mean   8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# std    2.775570e-17  2.775570e-17  2.775570e-17  2.775570e-17  2.775570e-17
# min    8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 25%    8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 50%    8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# 75%    8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
# max    8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02  8.330000e-02
#
#              M29-31        M32-38          M39+
# count  1.120710e+05  1.120710e+05  1.120710e+05
# mean   8.330000e-02  8.330000e-02  8.330000e-02
# std    2.775570e-17  2.775570e-17  2.775570e-17
# min    8.330000e-02  8.330000e-02  8.330000e-02
# 25%    8.330000e-02  8.330000e-02  8.330000e-02
# 50%    8.330000e-02  8.330000e-02  8.330000e-02
# 75%    8.330000e-02  8.330000e-02  8.330000e-02
# max    8.330000e-02  8.330000e-02  8.330000e-02

# %%
print(f'There are {len(data["events"]["device_id"].unique())} unique devices in the event data')
print(f'There are {len(data["events"])} unique events')
print(f'There are {len(data["gender_age_train"]["device_id"].unique())} unique devices in the training data')
# Out:
# There are 60865 unique devices in the event data
# There are 3252950 unique events
# There are 74645 unique devices in the training data

# %% [markdown]
# First replace the chinese brands with their english names

# %%
# Join chinese brand names to their english equivalents
phone_brand_device_model = pd.merge(data["phone_brand_device_model"],
                                    data["chinese_to_english_brand"],
                                    left_on="phone_brand", right_on="chinese_brand", how="left")

# Fill nans for brands already in english
phone_brand_device_model["brand"] =\
    phone_brand_device_model["brand"].where(phone_brand_device_model["brand"].str.isalpha(),
                                                    phone_brand_device_model["phone_brand"].str.lower())

# We will just work with device brand for the time being
device_data = phone_brand_device_model[["device_id", "brand", "device_model"]]
device_data
# Out:
#                   device_id    brand   device_model
# 0      -8890648629457979026   xiaomi             红米
# 1       1277779817574759137   xiaomi           MI 2
# 2       5137427614288105724  samsung      Galaxy S4
# 3       3669464369358936369    SUGAR           时尚手机
# 4      -5019277647504317457  samsung  Galaxy Note 2
# ...                     ...      ...            ...
# 187240  7979541072208733273   xiaomi           MI 4
# 187241  -187404680852357705   xiaomi            红米2
# 187242 -2718274279595622821   xiaomi           MI 3
# 187243  3098391762071677791     vivo             X1
# 187244  7540390258631417003     vivo           Y22L
#
# [187245 rows x 3 columns]

# %%
print(f'There are {len(device_data["device_id"].unique())} unique devices in the device data')
# Get rid of duplicates in the device data
device_data_cln = device_data.drop_duplicates("device_id")
print(len(device_data_cln))
# Out:
# There are 186716 unique devices in the device data
# 186716

# %% [markdown]
# There are 6 age group categories for each gender

# %%
data["gender_age_train"]["group"].sort_values().unique()
# Out:
# ['22-', '23-26', '27-28', '29-31', '32-38', '39+']
# Categories (6, object): ['22-' < '23-26' < '27-28' < '29-31' < '32-38' < '39+']

# %% [markdown]
# These categories already include the gender but for the purpose of this analysis we will create <br>
# our own buckets use the actual age of the users to reduce the number of predicted classes

# %%
data["gender_age_train"].rename(columns={"group": "pre_grouped"}, inplace=True)
bins = [0, 22, 26, 28, 31, 38, 100]
labels = ["22-", "23-26", "27-28", "29-31", "32-38", "39+"]
data["gender_age_train"]["group"] = pd.cut(data["gender_age_train"]["age"], bins=bins, labels=labels)
data["gender_age_train"]
# Out:
#                  device_id gender  age pre_grouped pre_grouped  group
# 0     -8076087639492063270      M   35      M32-38       32-38  32-38
# 1     -2897161552818060146      M   35      M32-38       32-38  32-38
# 2     -8260683887967679142      M   35      M32-38       32-38  32-38
# 3     -4938849341048082022      M   30      M29-31       29-31  29-31
# 4       245133531816851882      M   30      M29-31       29-31  29-31
# ...                    ...    ...  ...         ...         ...    ...
# 74640  4682031842235089751      M   30      M29-31       29-31  29-31
# 74641 -9178703742877135986      M   30      M29-31       29-31  29-31
# 74642   180946546684162312      M   20        M22-         22-    22-
# 74643  1390702386071991851      M   37      M32-38       32-38  32-38
# 74644    89181010588227347      M   25      M23-26       23-26  23-26
#
# [74645 rows x 6 columns]

# %% [markdown]
# We'll proceed to join the device brand data to the train data

# %%
combined_data = data["gender_age_train"]
print(len(combined_data))
combined_data = pd.merge(combined_data, device_data_cln, on="device_id", how="left")
combined_data.drop(columns=["pre_grouped"], inplace=True)
# Out:
# 74645

# %% [markdown]
# Put together the event data before merging all.
# Start with app data:

# %%
# Join app labels to their label categories
app_labels = data["app_labels"].drop_duplicates()
app_labels = app_labels.merge(data["label_categories"], on="label_id")
app_labels
# Out:
#                      app_id  label_id    category
# 0       7324884708820027918       251     Finance
# 1      -4494216993218550286       251     Finance
# 2       8756705988821000489       251     Finance
# 3       1061207043315821111       251     Finance
# 4      -1491198667294647703       251     Finance
# ...                     ...       ...         ...
# 459447 -5364349117796323466       985  Word games
# 459448  6320161160475087425       985  Word games
# 459449  7641656572760613661       985  Word games
# 459450 -2037260970074339790       985  Word games
# 459451  4912967798547629854       985  Word games
#
# [459452 rows x 3 columns]

# %% [markdown]
# For each entry in the events data there is a number of apps in the app events table that the user used during their session

# %%
# Join events to their app events
events = data["events"]
events = events.merge(data["app_events"], on="event_id", how="left")

# Use app events to join events to the app labels
events = events.merge(app_labels, on="app_id", how="left")
events.sort_values(by="category")
# Out:
#           event_id            device_id            timestamp  longitude  \
# 27741865   2545490  2241767092438554986  2016-05-01 06:48:43     119.94
# 25742018   2360757 -8892004110917383868  2016-05-06 10:09:48       0.00
# 25741714   2360713 -8642981685332370359  2016-05-06 10:01:40       0.00
# 11596043   1064261 -2613769140653670990  2016-05-05 12:24:46       0.00
# 25739672   2360561  7683263732254566184  2016-05-02 22:54:45       0.00
# ...            ...                  ...                  ...        ...
# 35452563   3252948  7111660304904287709  2016-05-07 23:35:33     121.40
# 35452564   3252948  7111660304904287709  2016-05-07 23:35:33     121.40
# 35452565   3252948  7111660304904287709  2016-05-07 23:35:33     121.40
# 35452566   3252949  2786044170600788970  2016-05-07 23:36:03     111.19
# 35452567   3252950  3315513013457872370  2016-05-07 23:20:08     112.99
#
#           latitude        app_id  is_installed  is_active  label_id category
# 27741865     37.17  5.322487e+16           1.0        0.0     714.0   1 free
# 25742018      0.00 -4.986197e+15           1.0        1.0     714.0   1 free
# 25741714      0.00 -4.986197e+15           1.0        0.0     714.0   1 free
# 11596043      0.00 -4.986197e+15           1.0        0.0     714.0   1 free
# 25739672      0.00  5.322487e+16           1.0        0.0     714.0   1 free
# ...            ...           ...           ...        ...       ...      ...
# 35452563     31.18  4.348660e+18           1.0        1.0       NaN      NaN
# 35452564     31.18 -9.957269e+17           1.0        1.0       NaN      NaN
# 35452565     31.18  2.306067e+18           1.0        1.0       NaN      NaN
# 35452566     31.29           NaN           NaN        NaN       NaN      NaN
# 35452567     28.23           NaN           NaN        NaN       NaN      NaN
#
# [35452568 rows x 10 columns]

# %% [markdown]
# #### Filling nan values
# Drop event_id, app_id and label_id as they are not required for predictions

# %%
# Fill nan category values with "unknown"
events["category"].fillna("unknown", inplace=True)
# Fill in missing timestamps with 00:00:00 time
events["timestamp"].fillna("2016-05-01 00:00:00", inplace=True)
# Get time from timestamp object
events['timestamp'] = pd.to_datetime(events['timestamp'])
events["time"] = events['timestamp'].dt.time
bins = [-0.1, 6, 9, 12, 14, 17, 20, 23]
labels = ["00:00-06:00", "07:00-09:00", "10:00-12:00", "13:00-14:00", "15:00-17:00", "18:00-20:00", "21:00-23:00"]
events["time_group"] = pd.cut(events["timestamp"].dt.hour, bins=bins, labels=labels)

# %% [markdown]
# Group event data by device_id and time and get a list of all active and installed apps and category

# %%
# Ignore geographical information for the time being
grouped_events = events.groupby(["device_id"])\
    [["time_group", "is_installed", "is_active", "category"]].agg({"time_group": lambda x: list(set(x)), "is_installed": np.sum, "is_active": np.sum, "category": lambda x: list(set(x))}).reset_index()
grouped_events
# Out:
#                  device_id                                         time_group  \
# 0     -9222956879900151005  [13:00-14:00, 18:00-20:00, 21:00-23:00, 15:00-...
# 1     -9222661944218806987            [18:00-20:00, 21:00-23:00, 00:00-06:00]
# 2     -9222399302879214035            [13:00-14:00, 21:00-23:00, 10:00-12:00]
# 3     -9221825537663503111  [13:00-14:00, 00:00-06:00, 18:00-20:00, 21:00-...
# 4     -9221767098072603291  [13:00-14:00, 00:00-06:00, 18:00-20:00, 15:00-...
# ...                    ...                                                ...
# 60860  9220914901466458680  [18:00-20:00, 00:00-06:00, 13:00-14:00, 21:00-...
# 60861  9221586026451102237  [18:00-20:00, 13:00-14:00, 00:00-06:00, 21:00-...
# 60862  9222110179000857683                         [18:00-20:00, 10:00-12:00]
# 60863  9222355582733155698                                      [18:00-20:00]
# 60864  9222539910510672930                                      [15:00-17:00]
#
#        is_installed  is_active  \
# 0            1504.0      710.0
# 1              64.0       46.0
# 2             388.0       20.0
# 3             457.0      252.0
# 4             155.0       79.0
# ...             ...        ...
# 60860         857.0       88.0
# 60861         445.0       70.0
# 60862         284.0       30.0
# 60863         135.0       46.0
# 60864          27.0        2.0
#
#                                                 category
# 0                                              [unknown]
# 1                                              [unknown]
# 2                                              [unknown]
# 3                                              [unknown]
# 4                                              [unknown]
# ...                                                  ...
# 60860  [Industry tag, Property Industry 2.0, Personal...
# 60861                                [unknown, Contacts]
# 60862  [Financial Services, Industry tag, And the Chu...
# 60863                                          [unknown]
# 60864                                          [unknown]
#
# [60865 rows x 5 columns]

# %%
combined_data = pd.merge(combined_data, grouped_events, on="device_id", how="left")
combined_data.sort_values(by="brand")
# Out:
#                  device_id gender  age  group    brand device_model  \
# 6085   -231815432814429273      M   28  27-28      AUX        V965T
# 31531  8567026160899753334      F   41    39+      AUX        V965T
# 54106  5489607796787403797      F   43    39+      AUX        V965T
# 38470 -4567000646686758042      M   63    39+      AUX        V965T
# 60798  4844629161497691306      M   40    39+  Bacardi           V6
# ...                    ...    ...  ...    ...      ...          ...
# 57155  8109205969894662857      M   40    39+      飞利浦        W6618
# 28536  6588287214961767693      F   31  29-31       首云           P1
# 63421 -1527969048433963834      M   34  32-38       首云           P1
# 62833 -6193284194987082936      F   29  29-31       首云           P1
# 49156  1751236410718403505      M   20    22-       鲜米         s800
#
#                                               time_group  is_installed  \
# 6085                                                 NaN           NaN
# 31531                                                NaN           NaN
# 54106                                                NaN           NaN
# 38470                                                NaN           NaN
# 60798  [18:00-20:00, 07:00-09:00, 13:00-14:00, 10:00-...         408.0
# ...                                                  ...           ...
# 57155                                                NaN           NaN
# 28536                                                NaN           NaN
# 63421                                                NaN           NaN
# 62833                                                NaN           NaN
# 49156  [18:00-20:00, 00:00-06:00, 15:00-17:00, 10:00-...         128.0
#
#        is_active                                           category
# 6085         NaN                                                NaN
# 31531        NaN                                                NaN
# 54106        NaN                                                NaN
# 38470        NaN                                                NaN
# 60798      102.0  [Industry tag, Property Industry 2.0, Personal...
# ...          ...                                                ...
# 57155        NaN                                                NaN
# 28536        NaN                                                NaN
# 63421        NaN                                                NaN
# 62833        NaN                                                NaN
# 49156      108.0                                          [unknown]
#
# [74645 rows x 10 columns]

# %%
device_ids = list(data["events"]["device_id"].unique())

device_events = len(combined_data["device_id"].loc[combined_data["device_id"].isin(device_ids)])

# %%
len(device_ids)
# Out:
# 60865

# %%
print(f"Only {round(device_events/len(device_ids)*100, 0)}% of the devices in the training data have event data associated to them")
# Out:
# Only 38.0% of the devices in the training data have event data associated to them

# %%
# Fill nan category values with "unknown"
# combined_data["category"].fillna("unknown", inplace=True)
# combined_data["category"].loc[combined_data["category"]=="unknown"] = combined_data["category"].loc[combined_data["category"]=="unknown"].apply(lambda x: [x])
# Fill is_installed and is_active category values with 3 for "unknown"
# combined_data[["is_installed", "is_active"]] = combined_data[["is_installed", "is_active"]].apply(lambda x: x.fillna(0))
# Fill nan longitude and latitude values with 0
# combined_data[["longitude", "latitude"]] = combined_data[["longitude", "latitude"]].apply(lambda x: x.fillna(0))
# Fill in missing timestamps with 00:00:00 time
# combined_data["time"].fillna("00:00:00", inplace=True)

# %%
combined_data.isna().sum()
# Out:
# device_id           0
# gender              0
# age                 0
# group               0
# brand               0
# device_model        0
# time_group      51336
# is_installed    51336
# is_active       51336
# category        51336
# dtype: int64

# %% [markdown]
# In order to use the coordinates we will group them into clusters
# This [tutorial](https://levelup.gitconnected.com/clustering-gps-co-ordinates-forming-regions-4f50caa7e4a1) demonstrates clustering latitude-longitude spatial data with DBSCAN/haversine and avoids Euclidean-distance problems.

# %%
# Clean coordinates from nan values
# coords = combined_data[['longitude', 'latitude']].dropna()
# coord_values = coords.values

# %%
# db = DBSCAN(eps=0.5, min_samples=10000, algorithm='ball_tree', metric='haversine').fit(np.radians(coord_values))

# %% [markdown]
# # Approach 1

# %% [markdown]
# Since most of the devices do not have event data we will first attempt to infer gender and age using only the device brand and model data

# %% [markdown]
# #### Split dataset into train, validation and test sets.

# %%
FEATURE_COLUMNS = ["brand", "device_model", "time_group", "is_installed", "is_active", "category"]
LABELS = ["gender", "group"]

# Prepare the labels
y = combined_data[LABELS]
y = pd.get_dummies(y, prefix='', prefix_sep='')
y.sort_values(by="F")

# %%
# Prepare the features
X = combined_data[FEATURE_COLUMNS]
X

# %%
# One hot encode app category field
mlb = MultiLabelBinarizer()
X = X.join(pd.DataFrame(mlb.fit_transform(X.pop("category")),
                        columns=mlb.classes_,
                        index=X.index))

# %%
X.sort_values(by="brand")

# %%
one_hot_brands = pd.get_dummies(X["brand"], prefix='', prefix_sep='')

# %%
one_hot_brands.columns

# %%
# Split into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# Split into train set further into train and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1)

# %% [markdown]
# #### Predictions
#
# We will first try to predict the gender and then use that to predict the age group since the age group bucket will depend on the gender
